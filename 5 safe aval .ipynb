# %% [markdown]
# <img src="https://raw.githubusercontent.com/sepidehrezvani/s/main/Capture_2025_02_27_17_01_52_74.png" width="500"/>
#
#
# # مشخصات زمانی و فرکانسی سیگنال‌ها و سیستم‌ها
#
# ## 6-0 مقدمه
# توصیف یک سیستم LTI بر حسب پاسخ فرکانسی جایگزینی برای توصیف حوزه زمان سیستم بر حسب کانولوشن است. در تحلیل سیستم‌های LTI غالباً استفاده از حوزه فرکانسی مناسب‌تر است زیرا معادلات دیفرانسیل و تفاضلی و عمل کانولوشن در حوزه فرکانس به عملیات جبری تبدیل می‌شوند. همچنین مفاهیمی چون فرکانس‌گزینی را در حوزه فرکانس می‌توان راحت تصور کرد. البته در طراحی سیستم معمولاً باید هم ملاحظات حوزه فرکانس منظور شود و هم ملاحظات حوزه زمان.
#
# ## 6-1 نمایش اندازه - فاز تبدیل فوریه
# تبدیل فوریه در حالت کلی مختلط است و همان‌طور که قبلاً گفته‌ایم می‌توان آن را با بخش‌های حقیقی و موهومی یا اندازه و فازش نشان داد. نمایش اندازه - فاز تبدیل فوریه پیوسته در زمان $$  X(j\omega) $$   عبارت است از:
#
# $$
# X(j\omega) = |X(j\omega)| e^{j\angle X(j\omega)}
# $$

# %% [markdown]
# به نحوی مشابه نمایش اندازه - فاز تبدیل فوریه گسسته در زمان  X(jw)  عبارت است از:
#
# $$(2-6)$$
# $$ X(j\omega) = |X(j\omega)| e^{j\angle X(j\omega)} $$
#
# در بحث زیر راجع به نمایش‌های اندازه - فاز توجه عمده خود را روی حالت پیوسته در زمان متمرکز می‌کنیم. نکات اصلی را به حالت گسسته در زمان نیز می‌توان اعمال کرد.
#
# از معادله ترکیب تبدیل فوریه یعنی معادله (4-8) چنین بر می‌آید که می‌توان  X(jw)  را تجزیه‌ی سیگنال  X(t) به مجموع نمایی‌های مختلط با فرکانس‌های مختلف دانست. در حقیقت، چنان که در بخش (7-3-4) گفتیم،  |X(jw)|^2  را می‌توان طیف چگالی انرژی  X(t)  دانست. یعنی:
#
# $$ |X(j\omega)|^2 \frac{d\omega}{2\pi} $$
#
# را می‌توان انرژی واقع در باند فرکانسی بی‌نهایت کوچک بین w و w+dw فرض کرد. پس اندازه‌ی  |X(jw)|  محتوای فرکانسی سیگنال را نشان می‌دهد، یعنی  |X(jw)|  اطلاعات مربوط به اندازه نسبی نمایی‌های مختلط تشکیل‌دهنده‌ی  X(t)  را در بر دارد. مثلاً اگر در خارج یک باند فرکانسی کوچک حول صفر داشته باشیم  |X(jw)| = 0 ،  X(t)  تنها نوسان‌های فرکانس پایین دارد.
#
# ولی زاویه فاز   <X(jw)  بر اندازه‌ی مولفه‌های فرکانسی اثری ندارد، بلکه اطلاعات مربوط به فاز نسبی این نمایی‌ها را نشان می‌دهد. رابطه‌ی فاز موجود در  <X(jw)  اثر زیادی بر طبیعت سیگنال  X(t)  دارد و نوعاً اطلاعات زیادی در مورد سیگنال دارد. در واقع، بسته به تابع فاز می‌توانیم سیگنال‌هایی با ظاهر متفاوت به دست آوریم، حتی اگر تابع اندازه تغییر نکند. برای نمونه، دوباره مثال شکل 3-3 را در نظر بگیرید. در اینجا کشتی با جمع آثار سه موج روبروست که هر کدام با یک سیگنال سینوسی مدل شده‌اند. اگر این سه سینوسی دامنه‌ی ثابتی داشته باشند، بسته به فاز نسبی‌شان می‌توانند دامنه‌ی بسیار بزرگ یا کوچکی داشته باشند. پس فازها برای کشتی کاملاً مهم‌اند.
#
# به عنوان نمونه‌ی دیگری از اثر فاز، سیگنال زیر را در نظر بگیرید:
#
# $$(6-3)$$
# $$ x(t) = 1 + \frac{1}{2} \cos(2\pi t + \varphi_1) + \cos(4\pi t + \varphi_2) + \frac{2}{3} \cos(6\pi t + \varphi_3) $$
#
# شکل 4-3 این سیگنال را به ازای $$ \varphi_1 = \varphi_2 = \varphi_3 = 0 $$ نشان می‌دهد. در شکل 1-6، این  X(t)  را به ازای چند فاز مخالف برای سینوس‌ها نشان داده‌ایم. همان‌طور که از شکل برمی‌آید، می‌بینیم که سیگنال حاصل برحسب مقادیر مختلف فاز نسبی چقدر می‌تواند متفاوت باشد.
#
# به طور کلی، تغییر تابع فاز  X(jw)  به تغییر مشخصات حوزه‌ی زمان سیگنال  X(t)  می‌انجامد. در بعضی موارد، اعوجاج فاز مهم است و در بعضی موارد نه. مثلاً یکی از خواص سیستم شنوایی انسان عدم حساسیت به فاز است. اگر تبدیل فوریه‌ی سیگنال یک صدای تنها (مثلاً یک مصوت) اعوجاج فاز داشته باشد، ولی اندازه‌اش تغییر نکند، قابلیت فهم آن تغییر زیادی نمی‌کند، گرچه شکل موج آن در حوزه‌ی زمان می‌تواند شکلی کاملاً دگرگون به خود بگیرد. هرچند اعوجاج ملایم فاز، نظیر اعوجاج تک‌صداها، قابلیت تشخیص را از بین نمی‌برد، ولی اعوجاج فاز شدید گفتار، مسلماً قابلیت تشخیص آن‌ها را از بین می‌برد.
#
# به عنوان مثالی بارز فرض کنید  x(t)  سیگنال ضبط‌شده‌ی بیان یک جمله است. اگر نوار وارونه پخش شود، سیگنال  X(-t)  به دست می‌آید و اثر متناظر در حوزه‌ی فرکانس، منفی شدن فاز است:
#
# $$ F\{x(-t)\} = X(-j\omega) = |X(j\omega)| e^{-j\angle X(j\omega)} $$

# %% [markdown]
# <img src="https://raw.githubusercontent.com/sepidehrezvani/s/main/Capture_2025_02_28_15_10_52_397.png" width="500"/>
#
# یعنی اندازه طیف نوار وارونه با طیف سیگنال اصلی برابرست و تنها فاز آن تغییر کرده است. واضح است که این تغییر فاز اثر مهمی بر قابلیت فهم صدای ضبط شده دارد.
#
# بررسی تصاویر مثال دیگری است که اهمیت فاز را نشان می‌دهد. همان‌طور که در فصل 3 به اختصار گفتیم، تصویر سیاه و سفید را می‌توان با سیگنال  x(t_1,t_2) نشان داد که   t_1 مختصه‌ی افقی نقطه‌ای از تصویر t_2 مختصه‌ی قائم آن نقطه و x(t_1,t_2) روشنی تصویر در (t_1,t_2) است. تبدیل فوریه X(jw_1,jw_2) \) تصویر تجزیه‌ی  x(t_1,t_2) به صورت نمایی‌های  e^{jw_1t_1} e^{jw_2t_2} \) را نشان می‌دهد که تغییرات مکان  x(t_1,t_2) \) در فرکانس‌های مختلف را در بر دارد.
#
# جنبه‌های مقدماتی تحلیل فوریه دو بعدی در مسائل  4-53  و 5-56  بررسی شده‌اند.
#
# در دیدن تصاویر، بخشی از مهم‌ترین اطلاعات در لبه‌ها و نواحی دارای کنتراست بالا نهفته است. نواحی دارای ماکزیمم و مینیمم روشنی در یک تصویر، محل‌هایی هستند که توابع نمایی مختلط دارای فرکانس‌های متفاوت هم‌فازند. بنابراین معقول است که تصور کنیم فاز تبدیل فوریه یک تصویر بخش اعظم اطلاعات راجع به تصویر را در بر داشته باشد و مخصوصاً اطلاعات راجع به لبه‌ها باید در فاز باشد.
#
# برای بررسی این تصور، شکل  1-4  را دوباره در شکل 6-2(الف)  نشان داده‌ایم. شکل  6-2(ب) اندازه‌ی تبدیل فوریه را نشان می‌دهد. در این شکل، محور افقی  w_1  و محور عمودی w_2  و روشنی تصویر در نقطه  (w_1,w_2) متناسب با اندازه‌ی تبدیل است.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/sepidehrezvani/s/main/Capture_2025_02_27_17_03_25_649.png" width="500"/>

# %% [markdown]
# X(jw1,jw2) تصویر شکل 2-6 (الف) است. فاز این تبدیل هم به نحوی مشابه در شکل 2-6 (ج) نشان داده شده است.
# شکل 2-6 (د) نتیجه صفر کردن فاز  X(jw1,jw2) ، حفظ اندازه تبدیل و گرفتن عکس تبدیل را نشان می‌دهد.
# در شکل 2-6 (ه) اندازه  X(jw1,jw2)  برابر یک قرار داده شده، ولی فاز حفظ شده است.
# سرانجام، شکل 2-6 (و) تصویر حاصل از گرفتن عکس تبدیل از تابعی با فاز نشان داده شده در شکل 2-6 (ج) و اندازه تبدیل تصویری کاملاً متفاوت، یعنی تصویر شکل 2-6 (ز) را نشان می‌دهد.
# این تصاویر به روشنی اهمیت فاز در نمایش تصاویر را نشان می‌دهند.
#
# ## نمایش اندازه - فاز پاسخ فرکانسی سیستم‌های LTI
#
# طبق خاصیت کانولوشن، تبدیل فوریه پیوسته در زمان  Y(jw)  خروجی یک سیستم LTI و تبدیل  X(jw)  ورودی آن به صورت زیر به هم مربوط می‌شوند:
#
# $$
# Y(j\omega) = H(j\omega) X(j\omega)
# $$
#
# که در آن  H(jw)  پاسخ فرکانسی سیستم، یعنی تبدیل فوریه پاسخ ضربه سیستم است.
# به نحوی مشابه، در حالت گسسته در زمان، تبدیل فوریه‌های ورودی  X(e^{jw})  و خروجی  Y(e^{jw})  سیستم LTI توسط پاسخ فرکانسی  H(e^{jw}) به هم مربوط می‌شوند:
#
# $$
# Y(e^{j\omega}) = H(e^{j\omega}) X(e^{j\omega}) \quad (4-6)
# $$
#
# پس اثر سیستم LTI بر ورودی، تغییر اندازه مولفه‌های فرکانسی آن است.
# اگر از دید نمایش اندازه - فاز به این اثر بنگریم، جزئیات بیشتری را خواهیم دید. در حالت پیوسته در زمان:
#
# $$
# |Y(j\omega)| = |H(j\omega)| |X(j\omega)| \quad (5-6)
# $$
#
# $$
# \angle Y(j\omega) = \angle H(j\omega) + \angle X(j\omega) \quad (6-6)
# $$
#
# در حالت گسسته در زمان نیز رابطه دقیقاً مشابهی وجود دارد.
# معادله (5-6) نشان می‌دهد که اثر یک سیستم LTI بر اندازه تبدیل فوریه ورودی، تغییر دادن مقیاس آن بر اساس پاسخ فرکانسی است.
# به همین دلیل  |H(jw)|  یا  |H(e^{jw})|  را غالباً **بهره سیستم** می‌نامند.
#
# معادله (6-6) نشان می‌دهد که سیستم LTI فاز ورودی  <X(jw)  را با افزودن فاز   <H(jw)  به آن تغییر می‌دهد.
# به همین دلیل  <H(j\omega)  را غالباً **جابجایی فاز سیستم** می‌نامند.
#
# جابجایی فاز سیستم می‌تواند رابطه نسبی فاز مؤلفه‌های ورودی را تغییر دهد و منجر به تغییر شدید چهره حوزه زمان ورودی شود،
# حتی در مواقعی که بهره سیستم در همه فرکانس‌ها ثابت است.
#
# تغییر اندازه و فاز توسط سیستم LTI می‌تواند **مطلوب یا نامطلوب** باشد، بسته به این که این تغییر چگونه صورت می‌گیرد.
# در حالت دوم، یعنی **نامطلوب بودن تغییر**، می‌گوییم دامنه و فاز **اعوجاج یافته‌اند**.
# در بخش‌های زیر مفاهیم و ابزارهایی برای ملموس کردن این اثرها پی‌ریزی خواهیم کرد.
